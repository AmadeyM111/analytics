# %%
df.head() # view datastructure
df.info() # view types
df.describe() # view distributions

df.isna().sum() # check NaN

train_test_split() # split dataset

model.fit() # learning
model.predict() # inference 

accuracy_score() # metric
